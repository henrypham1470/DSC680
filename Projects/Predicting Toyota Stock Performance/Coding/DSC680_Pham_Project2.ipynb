# %% [markdown]
# # Project 2
# # Henry Pham
# # Department of Data Science, Bellevue University
# # DSC680-T301
# # Professor: Amirfarrokh Iranitalab
# # Assignment Due Date: 2024-02-04

# %%
#----Project 2----

# %% [markdown]
# # Introduction

# %%
# This project is going to develop a predictive model that aims to shed light on the intricate dynamics affecting Toyota stock prices. 
# Rather than relying solely on traditional financial indicators, I will explore a comprehensive set of variables that includes 
# the stock performance of technology giants AMD and Intel, the tire manufacturer Good Year, the broader stock market index, 
# interest rates, consumer price index (CPI), and even a competitor in the automotive sector, Honda.

# %% [markdown]
# # Data Sources

# %%
# Interest rates: https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2023
# Stock market index: https://finance.yahoo.com/quote/SPY/history?p=SPY 
# Toyota: https://finance.yahoo.com/quote/TM/history?p=TM
# AMD: https://finance.yahoo.com/quote/AMD/history?p=AMD 
# Intel: https://finance.yahoo.com/quote/INTC/history?p=INTC 
# Goodyear Tire: https://finance.yahoo.com/quote/GT/history?p=GT  
# Honda: https://finance.yahoo.com/quote/HMC/history?p=HMC   
# CPI: https://www.alphavantage.co/query?function=CPI&interval=monthly&apikey=demo

# %% [markdown]
# # Required Libraries

# %%
# matplotlib: data visualization library for Python, widely used in data analysis, scientific research, engineering, and visualization tasks.
# numpy: numerical computations and data manipulation in Python.
# pandas: data manipulation, preprocessing, cleaning, transformation, exploration, and visualization.
# seaborn: a Python data visualization, widely used in data analysis, statistical modeling, and exploratory data analysis tasks.
# scikit-learn: also known as sklearn, provides an efficient framework for various machine learning tasks, such as classification, regression, clustering, dimensionality reduction, model selection, and preprocessing.
# scipy: a library for scientific computing in Python, provided a collection of mathematical algorithms and functionality such as optimization, interpolation, integration, linear algebra, signal processing, and statistics
# sqldf: a Python library that provides a SQL-like interface for querying pandas DataFrames using SQL syntax.
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Get stock market index data

# %%
# Import the pandas library
import pandas as pd
# Import the yfinance library
import yfinance as yf
# Import the YahooFinancials class from the yahoofinancials library. 
from yahoofinancials import YahooFinancials
# # Use the download function from the yfinance library to fetch historical SPY stock prices,
# symbol 'SPY' from January 1, 2019, to January 19, 2024. The fetched data is stored in a pandas DataFrame named 'spy_df'.
spy_df = yf.download('SPY', 
                      start='2019-01-01', 
                      end='2024-01-19', 
                      progress=False,
)
# Show few rows
spy_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02  245.979996  251.210007  245.949997  250.179993  230.557449
# 2019-01-03  248.229996  248.570007  243.669998  244.210007  225.055740
# 2019-01-04  247.589996  253.110001  247.169998  252.389999  232.594147
# 2019-01-07  252.690002  255.949997  251.690002  254.380005  234.428070
# 2019-01-08  256.820007  257.309998  254.000000  256.769989  236.630569
#
#                Volume
# Date
# 2019-01-02  126925200
# 2019-01-03  144140700
# 2019-01-04  142628800
# 2019-01-07  103139100
# 2019-01-08  102512600

# %%
# Export and save spy
spy_df.to_csv("C:\\DSC680\\Project2\\spy.csv")

# %% [markdown]
# # Get Toyota data

# %%
# Import the pandas library
import pandas as pd
# Import the yfinance library
import yfinance as yf
# Import the YahooFinancials class from the yahoofinancials library. 
from yahoofinancials import YahooFinancials
# # Use the download function from the yfinance library to fetch historical Toyota stock prices,
# symbol 'TM' from January 1, 2019, to January 19, 2024. The fetched data is stored in a pandas DataFrame named 'tm_df'.
tm_df = yf.download('TM', 
                      start='2019-01-01', 
                      end='2024-01-19', 
                      progress=False,
)
# Show few rows
tm_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2019-01-02  114.680000  116.529999  114.680000  116.279999  116.279999  169900
# 2019-01-03  115.849998  116.279999  114.290001  114.650002  114.650002  309500
# 2019-01-04  117.940002  120.169998  117.510002  119.730003  119.730003  307500
# 2019-01-07  120.709999  122.180000  120.320000  121.279999  121.279999  156100
# 2019-01-08  123.160004  123.480003  121.959999  122.309998  122.309998  150400

# %%
# Export and save tm
tm_df.to_csv("C:\\DSC680\\Project2\\tm.csv")

# %% [markdown]
# # Get AMD data

# %%
# Import the pandas library
import pandas as pd
# Import the yfinance library
import yfinance as yf
# Import the YahooFinancials class from the yahoofinancials library. 
from yahoofinancials import YahooFinancials
# # Use the download function from the yfinance library to fetch historical AMD stock prices,
# symbol 'AMD' from January 1, 2019, to January 19, 2024. The fetched data is stored in a pandas DataFrame named 'amd_df'.
amd_df = yf.download('AMD', 
                      start='2019-01-01', 
                      end='2024-01-19', 
                      progress=False,
)
# Show few rows
amd_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  18.010000  19.000000  17.980000  18.830000  18.830000   87148700
# 2019-01-03  18.420000  18.680000  16.940001  17.049999  17.049999  117277600
# 2019-01-04  17.549999  19.070000  17.430000  19.000000  19.000000  111878600
# 2019-01-07  19.440001  20.680000  19.000000  20.570000  20.570000  107157000
# 2019-01-08  21.190001  21.200001  19.680000  20.750000  20.750000  121271000

# %%
# Export and save amd
amd_df.to_csv("C:\\DSC680\\Project2\\amd.csv")

# %% [markdown]
# # Get Intel data

# %%
# Import the pandas library
import pandas as pd
# Import the yfinance library
import yfinance as yf
# Import the YahooFinancials class from the yahoofinancials library. 
from yahoofinancials import YahooFinancials
# # Use the download function from the yfinance library to fetch historical Intel stock prices,
# symbol 'INTC' from January 1, 2019, to January 19, 2024. The fetched data is stored in a pandas DataFrame named 'intc_df'.
intc_df = yf.download('INTC', 
                      start='2019-01-01', 
                      end='2024-01-19', 
                      progress=False,
)
# Show few rows
intc_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-01-02  45.959999  47.470001  45.770000  47.080002  41.060703  18774600
# 2019-01-03  46.150002  46.279999  44.389999  44.490002  38.801834  32267300
# 2019-01-04  45.840000  47.570000  45.540001  47.220001  41.182796  35447300
# 2019-01-07  47.099998  48.000000  46.750000  47.439999  41.374668  22736800
# 2019-01-08  47.799999  48.029999  46.779999  47.740002  41.636322  22749200

# %%
# Export and save intc
intc_df.to_csv("C:\\DSC680\\Project2\\intc.csv")

# %% [markdown]
# # Get GoodYear Tire data

# %%
# Import the pandas library
import pandas as pd
# Import the yfinance library
import yfinance as yf
# Import the YahooFinancials class from the yahoofinancials library. 
from yahoofinancials import YahooFinancials
# # Use the download function from the yfinance library to fetch historical GoodYear Tire stock prices,
# symbol 'GT' from January 1, 2019, to January 19, 2024. The fetched data is stored in a pandas DataFrame named 'gt_df'.
gt_df = yf.download('GT', 
                      start='2019-01-01', 
                      end='2024-01-19', 
                      progress=False,
)
# Show few rows
gt_df.head()
# Out:
#                  Open       High    Low      Close  Adj Close   Volume
# Date
# 2019-01-02  20.110001  20.980000  19.91  20.670000  19.677717  3224400
# 2019-01-03  20.440001  20.770000  20.25  20.309999  19.334997  2586000
# 2019-01-04  20.600000  21.350000  20.32  21.180000  20.163237  3027500
# 2019-01-07  21.240000  21.379999  20.84  21.000000  19.991877  5178300
# 2019-01-08  21.260000  21.500000  20.84  21.059999  20.048994  7401400

# %%
# Export and save gt
gt_df.to_csv("C:\\DSC680\\Project2\\gt.csv")

# %% [markdown]
# # Get Honda data

# %%
# Import the pandas library
import pandas as pd
# Import the yfinance library
import yfinance as yf
# Import the YahooFinancials class from the yahoofinancials library. 
from yahoofinancials import YahooFinancials
# # Use the download function from the yfinance library to fetch historical Honda stock prices,
# symbol 'HMC' from January 1, 2019, to January 19, 2024. The fetched data is stored in a pandas DataFrame named 'hmc_df'.
hmc_df = yf.download('HMC', 
                      start='2019-01-01', 
                      end='2024-01-19', 
                      progress=False,
)
# Show few rows
hmc_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2019-01-02  26.110001  26.590000  26.010000  26.480000  23.749647  655900
# 2019-01-03  26.400000  26.480000  26.059999  26.120001  23.426767  937000
# 2019-01-04  26.760000  27.440001  26.700001  27.309999  24.494066  826300
# 2019-01-07  27.540001  28.000000  27.450001  27.820000  24.951483  806700
# 2019-01-08  28.570000  28.750000  28.420000  28.480000  25.543428  949400

# %%
# Export and save hmc
hmc_df.to_csv("C:\\DSC680\\Project2\\hmc.csv")

# %% [markdown]
# # Get CPI data

# %%
# Import few libraries for working with data and making HTTP requests
import pandas as pd
import requests

# Set the Alpha Vantage API key
api_key = '2NJ0QDM5QCHNTJLL'

url = f'https://www.alphavantage.co/query?function=CPI&interval=monthly&apikey={api_key}'
r = requests.get(url)
data = r.json()

# Extracting the 'data' part from the JSON
data_list = data['data']

# Creating a DataFrame from the 'data' list
cpi_df = pd.DataFrame(data_list)

# Converting the 'date' column to datetime format
cpi_df['date'] = pd.to_datetime(cpi_df['date'])

# Converting the 'value' column to float format
cpi_df['value'] = cpi_df['value'].astype(float)

# Displaying few rows
cpi_df.head()
# Out:
#         date    value
# 0 2023-12-01  306.746
# 1 2023-11-01  307.051
# 2 2023-10-01  307.671
# 3 2023-09-01  307.789
# 4 2023-08-01  307.026

# %%
# Export and save cpi
cpi_df.to_csv("C:\\DSC680\\Project2\\cpi.csv")

# %% [markdown]
# # Get Interest rates data

# %% [markdown]
# ## Year 2024

# %%
# Import the pandas library
import pandas as pd

# Set the URL of the webpage that contains the table to be extracted. 
# The URL provided in this example leads to a webpage that contains daily treasury yield curve data for the year 2024.
url = 'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2024'

# Use the read_html() function from the pandas library to read the HTML table from the specified URL. 
# The read_html() function returns a list of DataFrames found in the HTML, and [0] is used to select the first DataFrame in the list. 
# The DataFrame is assigned to the variable rate_2023_df.
rate_2024_df = pd.read_html(url)[0]

# Show few rows
rate_2024_df.head()
# Out:
#          Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0  01/02/2024    NaN    NaN                   NaN                    NaN
# 1  01/03/2024    NaN    NaN                   NaN                    NaN
# 2  01/04/2024    NaN    NaN                   NaN                    NaN
# 3  01/05/2024    NaN    NaN                   NaN                    NaN
# 4  01/08/2024    NaN    NaN                   NaN                    NaN
#
#    COUPON EQUIVALENT  17 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.1  \
# 0                NaN                     NaN                  NaN
# 1                NaN                     NaN                  NaN
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#    52 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.2  ...  4 Mo  6 Mo  1 Yr  2 Yr  \
# ...

# %%
# Export and save rate_2024
rate_2024_df.to_csv("C:\\DSC680\\Project2\\rate_2024.csv")

# %% [markdown]
# ## Year 2023

# %%
# Import the pandas library
import pandas as pd

# Set the URL of the webpage that contains the table to be extracted. 
# The URL provided in this example leads to a webpage that contains daily treasury yield curve data for the year 2023.
url = 'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2023'

# Use the read_html() function from the pandas library to read the HTML table from the specified URL. 
# The read_html() function returns a list of DataFrames found in the HTML, and [0] is used to select the first DataFrame in the list. 
# The DataFrame is assigned to the variable rate_2023_df.
rate_2023_df = pd.read_html(url)[0]

# Show few rows
rate_2023_df.head()
# Out:
#          Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0  01/03/2023    NaN    NaN                   NaN                    NaN
# 1  01/04/2023    NaN    NaN                   NaN                    NaN
# 2  01/05/2023    NaN    NaN                   NaN                    NaN
# 3  01/06/2023    NaN    NaN                   NaN                    NaN
# 4  01/09/2023    NaN    NaN                   NaN                    NaN
#
#    COUPON EQUIVALENT  17 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.1  \
# 0                NaN                     NaN                  NaN
# 1                NaN                     NaN                  NaN
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#    52 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.2  ...  4 Mo  6 Mo  1 Yr  2 Yr  \
# ...

# %%
# Export and save rate_2023
rate_2023_df.to_csv("C:\\DSC680\\Project2\\rate_2023.csv")

# %% [markdown]
# ## Year 2022

# %%
# Import the pandas library
import pandas as pd

# Set the URL of the webpage that contains the table to be extracted. 
# The URL provided in this example leads to a webpage that contains daily treasury yield curve data for the year 2022.
url = 'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2022'

# Use the read_html() function from the pandas library to read the HTML table from the specified URL. 
# The read_html() function returns a list of DataFrames found in the HTML, and [0] is used to select the first DataFrame in the list. 
# The DataFrame is assigned to the variable rate_2022_df.
rate_2022_df = pd.read_html(url)[0]

# Show few rows
rate_2022_df.head()
# Out:
#          Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0  01/03/2022    NaN    NaN                   NaN                    NaN
# 1  01/04/2022    NaN    NaN                   NaN                    NaN
# 2  01/05/2022    NaN    NaN                   NaN                    NaN
# 3  01/06/2022    NaN    NaN                   NaN                    NaN
# 4  01/07/2022    NaN    NaN                   NaN                    NaN
#
#    COUPON EQUIVALENT  17 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.1  \
# 0                NaN                     NaN                  NaN
# 1                NaN                     NaN                  NaN
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#    52 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.2  ...  4 Mo  6 Mo  1 Yr  2 Yr  \
# ...

# %%
# Export and save rate_2022
rate_2022_df.to_csv("C:\\DSC680\\Project2\\rate_2022.csv")

# %% [markdown]
# ## Year 2021

# %%
# Import the pandas library
import pandas as pd

# Set the URL of the webpage that contains the table to be extracted. 
# The URL provided in this example leads to a webpage that contains daily treasury yield curve data for the year 2021.
url = 'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2021'

# Use the read_html() function from the pandas library to read the HTML table from the specified URL. 
# The read_html() function returns a list of DataFrames found in the HTML, and [0] is used to select the first DataFrame in the list. 
# The DataFrame is assigned to the variable rate_2021_df.
rate_2021_df = pd.read_html(url)[0]

# Show few rows
rate_2021_df.head()
# Out:
#          Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0  01/04/2021    NaN    NaN                   NaN                    NaN
# 1  01/05/2021    NaN    NaN                   NaN                    NaN
# 2  01/06/2021    NaN    NaN                   NaN                    NaN
# 3  01/07/2021    NaN    NaN                   NaN                    NaN
# 4  01/08/2021    NaN    NaN                   NaN                    NaN
#
#    COUPON EQUIVALENT  17 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.1  \
# 0                NaN                     NaN                  NaN
# 1                NaN                     NaN                  NaN
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#    52 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.2  ...  4 Mo  6 Mo  1 Yr  2 Yr  \
# ...

# %%
# Export and save rate_2021
rate_2021_df.to_csv("C:\\DSC680\\Project2\\rate_2021.csv")

# %% [markdown]
# ## Year 2020

# %%
# Import the pandas library
import pandas as pd

# Set the URL of the webpage that contains the table to be extracted. 
# The URL provided in this example leads to a webpage that contains daily treasury yield curve data for the year 2020
url = 'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2020'

# Use the read_html() function from the pandas library to read the HTML table from the specified URL. 
# The read_html() function returns a list of DataFrames found in the HTML, and [0] is used to select the first DataFrame in the list. 
# The DataFrame is assigned to the variable rate_2020_df.
rate_2020_df = pd.read_html(url)[0]

# Show few rows
rate_2020_df.head()
# Out:
#          Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0  01/02/2020    NaN    NaN                   NaN                    NaN
# 1  01/03/2020    NaN    NaN                   NaN                    NaN
# 2  01/06/2020    NaN    NaN                   NaN                    NaN
# 3  01/07/2020    NaN    NaN                   NaN                    NaN
# 4  01/08/2020    NaN    NaN                   NaN                    NaN
#
#    COUPON EQUIVALENT  17 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.1  \
# 0                NaN                     NaN                  NaN
# 1                NaN                     NaN                  NaN
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#    52 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.2  ...  4 Mo  6 Mo  1 Yr  2 Yr  \
# ...

# %%
# Export and save rate_2020
rate_2020_df.to_csv("C:\\DSC680\\Project2\\rate_2020.csv")

# %% [markdown]
# ## Year 2019

# %%
# Import the pandas library
import pandas as pd

# Set the URL of the webpage that contains the table to be extracted. 
# The URL provided in this example leads to a webpage that contains daily treasury yield curve data for the year 2019
url = 'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2019'

# Use the read_html() function from the pandas library to read the HTML table from the specified URL. 
# The read_html() function returns a list of DataFrames found in the HTML, and [0] is used to select the first DataFrame in the list. 
# The DataFrame is assigned to the variable rate_2019_df.
rate_2019_df = pd.read_html(url)[0]

# Show few rows
rate_2019_df.head()
# Out:
#          Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0  01/02/2019    NaN    NaN                   NaN                    NaN
# 1  01/03/2019    NaN    NaN                   NaN                    NaN
# 2  01/04/2019    NaN    NaN                   NaN                    NaN
# 3  01/07/2019    NaN    NaN                   NaN                    NaN
# 4  01/08/2019    NaN    NaN                   NaN                    NaN
#
#    COUPON EQUIVALENT  17 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.1  \
# 0                NaN                     NaN                  NaN
# 1                NaN                     NaN                  NaN
# 2                NaN                     NaN                  NaN
# 3                NaN                     NaN                  NaN
# 4                NaN                     NaN                  NaN
#
#    52 WEEKS BANK DISCOUNT  COUPON EQUIVALENT.2  ...  4 Mo  6 Mo  1 Yr  2 Yr  \
# ...

# %%
# Export and save rate_2019
rate_2019_df.to_csv("C:\\DSC680\\Project2\\rate_2019.csv")

# %% [markdown]
# # Consolidate all interest rates (2019-2024) into one rate dataframe

# %%
# Import the pandas library
import pandas as pd

# Use the read_csv() function from the pandas library to read the CSV file located 
# at the specified file path (C:\\DSC680\\Project2\\rate_2024.csv). 
# The read_csv() function reads the CSV file and converts it into a pandas DataFrame.
# The DataFrame is assigned to the variable rate_2024.
rate_2024 = pd.read_csv('C:\\DSC680\\Project2\\rate_2024.csv')

# Repeat the same for the remaining years.
rate_2023 = pd.read_csv('C:\\DSC680\\Project2\\rate_2023.csv')
rate_2022 = pd.read_csv('C:\\DSC680\\Project2\\rate_2022.csv')
rate_2021 = pd.read_csv('C:\\DSC680\\Project2\\rate_2021.csv')
rate_2020 = pd.read_csv('C:\\DSC680\\Project2\\rate_2020.csv')
rate_2019 = pd.read_csv('C:\\DSC680\\Project2\\rate_2019.csv')

# %%
#  Create a new DataFrame called smaller_df by removing the specified columns from the original DataFrame data.

# The drop() function is used to remove specified columns from the DataFrame.
# ['20 YR', '30 YR'] is a list of column names that are removed from the DataFrame.
# axis=1 specifies that the columns should be dropped, as opposed to rows. 
smaller_rate_2024 = rate_2024.drop(['20 YR','30 YR'], axis=1)

# Repeat the same for the remaining years.
smaller_rate_2023 = rate_2023.drop(['20 YR','30 YR'], axis=1)
smaller_rate_2022 = rate_2022.drop(['20 YR','30 YR'], axis=1)
smaller_rate_2021 = rate_2021.drop(['20 YR','30 YR'], axis=1)
smaller_rate_2020 = rate_2020.drop(['20 YR','30 YR'], axis=1)
smaller_rate_2019 = rate_2019.drop(['20 YR','30 YR'], axis=1)

# %%
# Import sqldf function from the pandasql library. 
# The pandasql library provides a way to execute SQL queries on pandas DataFrames.
from pandasql import sqldf

# The query combines data from smaller_rate_2024, smaller_rate_2023, smaller_rate_2022, smaller_rate_2021, 
# smaller_rate_2020, and smaller_rate_2019
# using the UNION ALL operator.
# This results in a single DataFrame that contains the selected columns from all the specified DataFrames.
query = """
Select Date,[1 Mo],[2 Mo],[3 Mo],[4 Mo],[6 Mo],[1 Yr],[2 Yr],[3 Yr],[5 Yr],[7 Yr],[10 Yr],[20 Yr],[30 Yr] from smaller_rate_2024
UNION ALL
Select Date,[1 Mo],[2 Mo],[3 Mo],[4 Mo],[6 Mo],[1 Yr],[2 Yr],[3 Yr],[5 Yr],[7 Yr],[10 Yr],[20 Yr],[30 Yr] from smaller_rate_2023
UNION ALL
Select Date,[1 Mo],[2 Mo],[3 Mo],[4 Mo],[6 Mo],[1 Yr],[2 Yr],[3 Yr],[5 Yr],[7 Yr],[10 Yr],[20 Yr],[30 Yr] from smaller_rate_2022
UNION ALL
Select Date,[1 Mo],[2 Mo],[3 Mo],[4 Mo],[6 Mo],[1 Yr],[2 Yr],[3 Yr],[5 Yr],[7 Yr],[10 Yr],[20 Yr],[30 Yr] from smaller_rate_2021
UNION ALL
Select Date,[1 Mo],[2 Mo],[3 Mo],[4 Mo],[6 Mo],[1 Yr],[2 Yr],[3 Yr],[5 Yr],[7 Yr],[10 Yr],[20 Yr],[30 Yr] from smaller_rate_2020
UNION ALL
Select Date,[1 Mo],[2 Mo],[3 Mo],[4 Mo],[6 Mo],[1 Yr],[2 Yr],[3 Yr],[5 Yr],[7 Yr],[10 Yr],[20 Yr],[30 Yr] from smaller_rate_2019
"""

# %%
# Run the query
rate_df = sqldf(query)

# %%
# Show few rows
rate_df.head()
# Out:
#          Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0  01/02/2024  5.55  5.54  5.46  5.41  5.24  4.80  4.33  4.09  3.93  3.95
# 1  01/03/2024  5.54  5.54  5.48  5.41  5.25  4.81  4.33  4.07  3.90  3.92
# 2  01/04/2024  5.56  5.48  5.48  5.41  5.25  4.85  4.38  4.14  3.97  3.99
# 3  01/05/2024  5.54  5.48  5.47  5.41  5.24  4.84  4.40  4.17  4.02  4.04
# 4  01/08/2024  5.54  5.48  5.49  5.39  5.24  4.82  4.36  4.11  3.97  3.99
#
#    10 Yr  20 Yr  30 Yr
# 0   3.95   4.25   4.08
# 1   3.91   4.21   4.05
# 2   3.99   4.30   4.13
# 3   4.05   4.37   4.21
# 4   4.01   4.33   4.17

# %%
# Get the dimensions of a pandas DataFrame
rate_df.shape
# Out:
# (1269, 14)

# %%
# In the rate dataset, rename col '1 Yr' to 'daily_rate'
rate_df = rate_df.rename(columns={'1 Yr': 'daily_rate'})
# Display few rows in the new rate dataset.
rate_df.head()
# Out:
#          Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  daily_rate  2 Yr  3 Yr  5 Yr  \
# 0  01/02/2024  5.55  5.54  5.46  5.41  5.24        4.80  4.33  4.09  3.93
# 1  01/03/2024  5.54  5.54  5.48  5.41  5.25        4.81  4.33  4.07  3.90
# 2  01/04/2024  5.56  5.48  5.48  5.41  5.25        4.85  4.38  4.14  3.97
# 3  01/05/2024  5.54  5.48  5.47  5.41  5.24        4.84  4.40  4.17  4.02
# 4  01/08/2024  5.54  5.48  5.49  5.39  5.24        4.82  4.36  4.11  3.97
#
#    7 Yr  10 Yr  20 Yr  30 Yr
# 0  3.95   3.95   4.25   4.08
# 1  3.92   3.91   4.21   4.05
# 2  3.99   3.99   4.30   4.13
# 3  4.04   4.05   4.37   4.21
# 4  3.99   4.01   4.33   4.17

# %%
# Export and save consolidated rate
rate_df.to_csv("C:\\DSC680\\Project2\\rate.csv")

# %% [markdown]
# # Get the final dataset for rate, SPY, AMD, INTC, GT, HMC, TM and CPI

# %%
# Import the pandas library
import pandas as pd
# Read the csv files for rate, apple and spy.
rate = pd.read_csv("C:\\DSC680\\Project2\\rate.csv")
spy = pd.read_csv("C:\\DSC680\\Project2\\spy.csv")
tm = pd.read_csv("C:\\DSC680\\Project2\\tm.csv")
intc = pd.read_csv("C:\\DSC680\\Project2\\intc.csv")
amd = pd.read_csv("C:\\DSC680\\Project2\\amd.csv")
gt = pd.read_csv("C:\\DSC680\\Project2\\gt.csv")
hmc = pd.read_csv("C:\\DSC680\\Project2\\hmc.csv")
cpi = pd.read_csv("C:\\DSC680\\Project2\\cpi.csv")

# %%
# Cast Date col to datetime datatype in the rate dataset.
rate['Date'] = pd.to_datetime(rate['Date'], format='%m/%d/%Y')
# Show few rows
rate.head()
# Out:
#    Unnamed: 0       Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  daily_rate  2 Yr  \
# 0           0 2024-01-02  5.55  5.54  5.46  5.41  5.24        4.80  4.33
# 1           1 2024-01-03  5.54  5.54  5.48  5.41  5.25        4.81  4.33
# 2           2 2024-01-04  5.56  5.48  5.48  5.41  5.25        4.85  4.38
# 3           3 2024-01-05  5.54  5.48  5.47  5.41  5.24        4.84  4.40
# 4           4 2024-01-08  5.54  5.48  5.49  5.39  5.24        4.82  4.36
#
#    3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  30 Yr
# 0  4.09  3.93  3.95   3.95   4.25   4.08
# 1  4.07  3.90  3.92   3.91   4.21   4.05
# 2  4.14  3.97  3.99   3.99   4.30   4.13
# 3  4.17  4.02  4.04   4.05   4.37   4.21
# 4  4.11  3.97  3.99   4.01   4.33   4.17

# %%
# Cast Date col to datetime datatype in the SPY dataset.
spy['Date'] = pd.to_datetime(spy['Date'], format='%Y-%m-%d')
# Show few rows
spy.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2019-01-02  245.979996  251.210007  245.949997  250.179993  230.557449
# 1 2019-01-03  248.229996  248.570007  243.669998  244.210007  225.055740
# 2 2019-01-04  247.589996  253.110001  247.169998  252.389999  232.594147
# 3 2019-01-07  252.690002  255.949997  251.690002  254.380005  234.428070
# 4 2019-01-08  256.820007  257.309998  254.000000  256.769989  236.630569
#
#       Volume
# 0  126925200
# 1  144140700
# 2  142628800
# 3  103139100
# 4  102512600

# %%
# Cast Date col to datetime datatype in the aapl dataset.
tm['Date'] = pd.to_datetime(tm['Date'], format='%Y-%m-%d')
# Show few rows
tm.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2019-01-02  114.680000  116.529999  114.680000  116.279999  116.279999
# 1 2019-01-03  115.849998  116.279999  114.290001  114.650002  114.650002
# 2 2019-01-04  117.940002  120.169998  117.510002  119.730003  119.730003
# 3 2019-01-07  120.709999  122.180000  120.320000  121.279999  121.279999
# 4 2019-01-08  123.160004  123.480003  121.959999  122.309998  122.309998
#
#    Volume
# 0  169900
# 1  309500
# 2  307500
# 3  156100
# 4  150400

# %%
# Cast Date col to datetime datatype in the INTC dataset.
intc['Date'] = pd.to_datetime(intc['Date'], format='%Y-%m-%d')
# Show few rows
intc.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2019-01-02  45.959999  47.470001  45.770000  47.080002  41.060703  18774600
# 1 2019-01-03  46.150002  46.279999  44.389999  44.490002  38.801834  32267300
# 2 2019-01-04  45.840000  47.570000  45.540001  47.220001  41.182796  35447300
# 3 2019-01-07  47.099998  48.000000  46.750000  47.439999  41.374668  22736800
# 4 2019-01-08  47.799999  48.029999  46.779999  47.740002  41.636322  22749200

# %%
# Cast Date col to datetime datatype in the AMD dataset.
amd['Date'] = pd.to_datetime(amd['Date'], format='%Y-%m-%d')
# Show few rows
amd.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2019-01-02  18.010000  19.000000  17.980000  18.830000  18.830000   87148700
# 1 2019-01-03  18.420000  18.680000  16.940001  17.049999  17.049999  117277600
# 2 2019-01-04  17.549999  19.070000  17.430000  19.000000  19.000000  111878600
# 3 2019-01-07  19.440001  20.680000  19.000000  20.570000  20.570000  107157000
# 4 2019-01-08  21.190001  21.200001  19.680000  20.750000  20.750000  121271000

# %%
# Cast Date col to datetime datatype in the INTC dataset.
gt['Date'] = pd.to_datetime(gt['Date'], format='%Y-%m-%d')
# Show few rows
gt.head()
# Out:
#         Date       Open       High    Low      Close  Adj Close   Volume
# 0 2019-01-02  20.110001  20.980000  19.91  20.670000  19.677717  3224400
# 1 2019-01-03  20.440001  20.770000  20.25  20.309999  19.334997  2586000
# 2 2019-01-04  20.600000  21.350000  20.32  21.180000  20.163237  3027500
# 3 2019-01-07  21.240000  21.379999  20.84  21.000000  19.991877  5178300
# 4 2019-01-08  21.260000  21.500000  20.84  21.059999  20.048994  7401400

# %%
# Cast Date col to datetime datatype in the INTC dataset.
hmc['Date'] = pd.to_datetime(hmc['Date'], format='%Y-%m-%d')
# Show few rows
hmc.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  Volume
# 0 2019-01-02  26.110001  26.590000  26.010000  26.480000  23.749647  655900
# 1 2019-01-03  26.400000  26.480000  26.059999  26.120001  23.426767  937000
# 2 2019-01-04  26.760000  27.440001  26.700001  27.309999  24.494066  826300
# 3 2019-01-07  27.540001  28.000000  27.450001  27.820000  24.951483  806700
# 4 2019-01-08  28.570000  28.750000  28.420000  28.480000  25.543428  949400

# %%
# Cast Date col to datetime datatype in the INTC dataset.
cpi['date'] = pd.to_datetime(cpi['date'], format='%Y-%m-%d')
# Show few rows
cpi.head()
# Out:
#    Unnamed: 0       date    value
# 0           0 2023-12-01  306.746
# 1           1 2023-11-01  307.051
# 2           2 2023-10-01  307.671
# 3           3 2023-09-01  307.789
# 4           4 2023-08-01  307.026

# %%
# import sqldf
from pandasql import sqldf
# Join rate variable with remaining variables, and create some new cols in the final dataset.

query = """
WITH cpi_val AS
(
Select
date, value, strftime('%Y', date) AS cpi_year, strftime('%m', date) AS cpi_month
From cpi
)
, rates AS
(
Select
A.Date, A.daily_rate, A.[1 Mo], A.[2 Mo],A.[3 Mo],A.[4 Mo],A.[6 Mo],
A.[2 Yr], A.[3 Yr], A.[5 Yr], A.[7 Yr], A.[10 Yr], A.[20 Yr], A.[30 Yr],
strftime('%Y', A.Date) AS rate_year, strftime('%m', A.Date) AS rate_month,
ROW_NUMBER() OVER(ORDER BY A.Date) AS Id -- Create an Id col to sort the Date
From rate as A
)
, join_rateAndcpi AS
(
Select
A.Date, A.daily_rate, A.[1 Mo], A.[2 Mo],A.[3 Mo],A.[4 Mo],A.[6 Mo],
A.[2 Yr], A.[3 Yr], A.[5 Yr], A.[7 Yr], A.[10 Yr], A.[20 Yr], A.[30 Yr],
A.rate_year, A.rate_month, A.Id,
B.value AS cpi_value
From rates AS A
Inner Join cpi_val AS B
ON A.rate_year = B.cpi_year AND A.rate_month = B.cpi_month
)
, join_allvariables AS
(
Select
A.Date, A.Id, A.daily_rate, A.[1 Mo], A.[2 Mo],A.[3 Mo],A.[4 Mo],A.[6 Mo],
A.[2 Yr], A.[3 Yr], A.[5 Yr], A.[7 Yr], A.[10 Yr], A.[20 Yr], A.[30 Yr], A.cpi_value,

B.Close as spy_closePrice, --Replace headers
B.Open as spy_OpenPrice, --Replace headers
B.High as spy_HighPrice,  --Replace headers
B.Low as spy_lowPrice, --Replace headers
B.Volume as spy_volumn, --Replace headers

C.[Close] as tm_closePrice, --Replace headers
C.[Volume] as tm_volumn, --Replace headers
C.Open as tm_OpenPrice, --Replace headers
C.High as tm_HighPrice, --Replace headers
C.Low as tm_LowPrice, --Replace header

D.[Close] as intc_closePrice, --Replace headers
D.[Volume] AS intc_volumn, --Replace headers
D.Open AS intc_OpenPrice, --Replace headers
D.High as intc_HighPrice, --Replace headers
D.Low as intc_LowPrice, --Replace header

E.[Close] as amd_closePrice, --Replace headers
E.[Volume] AS amd_volumn, --Replace headers
E.Open AS amd_OpenPrice, --Replace headers
E.High as amd_HighPrice, --Replace headers
E.Low as amd_LowPrice, --Replace header

F.[Close] as gt_closePrice, --Replace headers
F.[Volume] as gt_volumn, --Replace headers
F.Open as gt_OpenPrice, --Replace headers
F.High as gt_HighPrice, --Replace headers
F.Low as gt_LowPrice, --Replace header

G.[Close] as hmc_closePrice, --Replace headers
G.[Volume] as hmc_volumn, --Replace headers
G.Open as hmc_OpenPrice, --Replace headers
G.High as hmc_HighPrice, --Replace headers
G.Low as hmc_LowPrice --Replace header

From join_rateAndcpi AS A
Inner Join spy AS B --join rate with spy
ON A.Date = B.Date
Inner Join tm AS C --join rate with Toyota
On A.Date = C.Date
Inner Join intc AS D --join rate with intc
On A.Date = D.Date
Inner Join amd AS E --join rate with amd
On A.Date = E.Date
Inner Join gt as F --join rate with GoodYear
On A.Date = F.Date
Inner Join hmc as G --join rate with Honda
On A.Date = G.Date
)
, create_newCol_featureEngr AS
(
Select
--new col Lead_tm (Toyota)
LEAD(tm_closePrice, 1) OVER(Order by Id) as Lead_tm,
Date, Id, daily_rate, [1 Mo], [2 Mo], [3 Mo], [4 Mo], [6 Mo],
[2 Yr], [3 Yr], [5 Yr], [7 Yr], [10 Yr], [20 Yr], [30 Yr], cpi_value,

spy_closePrice, 
spy_OpenPrice, 
spy_HighPrice, 
spy_lowPrice, 
spy_volumn, 

tm_closePrice, 
tm_volumn, 
tm_OpenPrice, 
tm_HighPrice,  
tm_LowPrice,

intc_closePrice, 
intc_volumn, 
intc_OpenPrice, 
intc_HighPrice,  
intc_LowPrice,

amd_closePrice, 
amd_volumn, 
amd_OpenPrice, 
amd_HighPrice,  
amd_LowPrice,

gt_closePrice, 
gt_volumn, 
gt_OpenPrice, 
gt_HighPrice,  
gt_LowPrice,

hmc_closePrice, 
hmc_volumn, 
hmc_OpenPrice, 
hmc_HighPrice,  
hmc_LowPrice

From join_allvariables
)
,final_dataset as
(
Select
Lead_tm, tm_closePrice, 

(tm_closePrice - Lead_tm) AS tm_point_change,  --new col tm_point_change
CASE 
WHEN (tm_closePrice-Lead_tm) < 0 THEN 'Down-day'
WHEN (tm_closePrice-Lead_tm) > 0 THEN 'Up-day'
END AS tm_Indication,  --new col tm_Indication,

Date, Id, daily_rate, [1 Mo], [2 Mo], [3 Mo], [6 Mo], [2 Yr], [3 Yr], [5 Yr], [7 Yr], [10 Yr], [20 Yr], [30 Yr], cpi_value,

tm_OpenPrice, tm_HighPrice, tm_lowPrice, tm_volumn,

spy_closePrice, spy_volumn, spy_OpenPrice, spy_HighPrice, spy_LowPrice,

intc_closePrice, intc_volumn, intc_OpenPrice, intc_HighPrice, intc_LowPrice,

amd_closePrice, amd_volumn, amd_OpenPrice, amd_HighPrice, amd_LowPrice,

gt_closePrice, gt_volumn, gt_OpenPrice, gt_HighPrice, gt_LowPrice,

hmc_closePrice, hmc_volumn, hmc_OpenPrice, hmc_HighPrice, hmc_LowPrice

From create_newCol_featureEngr
)
Select
tm_closePrice, tm_point_change, tm_Indication, spy_closePrice, intc_closePrice, amd_closePrice, gt_closePrice, hmc_closePrice,
cpi_value, Date, Id, daily_rate, [1 Mo], [2 Mo], [3 Mo], [6 Mo], [2 Yr], [3 Yr], [5 Yr], [7 Yr], [10 Yr], [20 Yr], [30 Yr],
spy_OpenPrice, spy_HighPrice, spy_lowPrice, spy_volumn, 
tm_volumn, tm_OpenPrice, tm_HighPrice, tm_LowPrice,
intc_OpenPrice, intc_HighPrice, intc_lowPrice, intc_volumn,
amd_OpenPrice, amd_HighPrice, amd_lowPrice, amd_volumn,
gt_OpenPrice, gt_HighPrice, gt_lowPrice, gt_volumn,
hmc_OpenPrice, hmc_HighPrice, hmc_lowPrice, hmc_volumn

From final_dataset
WHERE tm_point_change is not null AND tm_Indication is not null
"""

# %%
# Run the query
final_df = sqldf(query)

# %%
# Show final dataset records
final_df
# Out:
#       tm_closePrice  tm_point_change tm_Indication  spy_closePrice  \
# 0        116.279999         1.629997        Up-day      250.179993
# 1        114.650002        -5.080002      Down-day      244.210007
# 2        119.730003        -1.549995      Down-day      252.389999
# 3        121.279999        -1.029999      Down-day      254.380005
# 4        122.309998        -0.610001      Down-day      256.769989
# ...             ...              ...           ...             ...
# 1241     180.860001         2.330002        Up-day      472.700012
# 1242     178.529999        -1.320007      Down-day      473.649994
# 1243     179.850006        -0.869995      Down-day      475.649994
# 1244     180.720001        -0.389999      Down-day      476.510010
# 1245     181.110001        -2.270004      Down-day      476.690002
#
#       intc_closePrice  amd_closePrice  gt_closePrice  hmc_closePrice  \
# 0           47.080002       18.830000      20.670000       26.480000
# ...

# %%
# Export and save the final dataset
final_df.to_csv("C:\\DSC680\\Project2\\Final_dataset.csv")

# %% [markdown]
# # Data Cleaning

# %%
# Check the dimension of the final dataset.
final_df.shape
# Out:
# (1246, 47)

# %%
print('Number of rows: ', final_df.shape[0])
print('Number of columns: ', final_df.shape[1])
# Out:
# Number of rows:  1246
# Number of columns:  47

# %%
# Check the datatype of each column
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1246 entries, 0 to 1245
# Data columns (total 47 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tm_closePrice    1246 non-null   float64
#  1   tm_point_change  1246 non-null   float64
#  2   tm_Indication    1246 non-null   object
#  3   spy_closePrice   1246 non-null   float64
#  4   intc_closePrice  1246 non-null   float64
#  5   amd_closePrice   1246 non-null   float64
#  6   gt_closePrice    1246 non-null   float64
#  7   hmc_closePrice   1246 non-null   float64
#  8   cpi_value        1246 non-null   float64
#  9   Date             1246 non-null   object
#  10  Id               1246 non-null   int64
#  11  daily_rate       1246 non-null   float64
#  12  1 Mo             1246 non-null   float64
#  13  2 Mo             1246 non-null   float64
#  14  3 Mo             1246 non-null   float64
#  15  6 Mo             1246 non-null   float64
# ...

# %%
# Check missing values
final_df.isnull().sum()
# Out:
# tm_closePrice      0
# tm_point_change    0
# tm_Indication      0
# spy_closePrice     0
# intc_closePrice    0
# amd_closePrice     0
# gt_closePrice      0
# hmc_closePrice     0
# cpi_value          0
# Date               0
# Id                 0
# daily_rate         0
# 1 Mo               0
# 2 Mo               0
# 3 Mo               0
# 6 Mo               0
# 2 Yr               0
# 3 Yr               0
# 5 Yr               0
# 7 Yr               0
# 10 Yr              0
# 20 Yr              0
# 30 Yr              0
# spy_OpenPrice      0
# spy_HighPrice      0
# spy_LowPrice       0
# spy_volumn         0
# tm_volumn          0
# tm_OpenPrice       0
# tm_HighPrice       0
# tm_lowPrice        0
# intc_OpenPrice     0
# intc_HighPrice     0
# intc_LowPrice      0
# intc_volumn        0
# amd_OpenPrice      0
# amd_HighPrice      0
# amd_LowPrice       0
# amd_volumn         0
# gt_OpenPrice       0
# gt_HighPrice       0
# gt_LowPrice        0
# gt_volumn          0
# ...

# %%
# There is no missing values in the final dataset.

# %%
# Check duplicates
final_df.duplicated().sum()
# Out:
# 0

# %%
# There is no duplicates

# %%
# list col names in the final dataset.
for col in final_df:
    print(col)
# Out:
# tm_closePrice
# tm_point_change
# tm_Indication
# spy_closePrice
# intc_closePrice
# amd_closePrice
# gt_closePrice
# hmc_closePrice
# cpi_value
# Date
# Id
# daily_rate
# 1 Mo
# 2 Mo
# 3 Mo
# 6 Mo
# 2 Yr
# 3 Yr
# 5 Yr
# 7 Yr
# 10 Yr
# 20 Yr
# 30 Yr
# spy_OpenPrice
# spy_HighPrice
# spy_LowPrice
# spy_volumn
# tm_volumn
# tm_OpenPrice
# tm_HighPrice
# tm_lowPrice
# intc_OpenPrice
# intc_HighPrice
# intc_LowPrice
# intc_volumn
# amd_OpenPrice
# amd_HighPrice
# amd_LowPrice
# amd_volumn
# gt_OpenPrice
# gt_HighPrice
# gt_LowPrice
# gt_volumn
# hmc_OpenPrice
# hmc_HighPrice
# hmc_LowPrice
# hmc_volumn

# %%
# Overall stats summary
final_df.describe()
# Out:
#        tm_closePrice  tm_point_change  spy_closePrice  intc_closePrice  \
# count    1246.000000      1246.000000     1246.000000      1246.000000
# mean      149.780385        -0.053852      374.704463        46.960931
# std        22.131252         2.274134       63.197283        10.896226
# min       108.500000       -12.900009      222.949997        24.900000
# 25%       132.429993        -1.199997      312.192497        37.230000
# 50%       143.224998        -0.119999      389.750000        49.195000
# 75%       168.462502         1.117496      429.440010        55.254999
# max       211.369995        10.590004      477.709991        68.470001
#
#        amd_closePrice  gt_closePrice  hmc_closePrice    cpi_value  \
# count     1246.000000    1246.000000     1246.000000  1246.000000
# mean        77.984005      13.865971       27.537681   276.523823
# std         32.932568       3.861245        2.959124    19.534005
# ...

# %%
# Statistical summary of the final dataset to check whether mean and median are close to each other.

# daily_rate: positive skewed because mean > median.
# spy_closePrice: negative skewed because mean < median.
# tm_closePrice: positive skewed because mean > median.
# intc_closePrice: negative skewed because mean < median.
# amd_closePrice: negative skewed because mean < median.
# gt_closePrice: positive skewed because mean > median.
# hmc_closePrice: positive skewed because mean > median.
# cpi_value: positive skewed because mean > median.

# %%
# Check for outliers.
# I use box plot and z-scores to check whether there are outliers.

# %%
# Subset the data for the variables of interest rate, stock market indices, Toyota stock prices,
# Intel stock prices, AMD stock prices, GoodYear stock prices, Honda stock prices, and CPI values
interest_rate = final_df['daily_rate']
stock_market = final_df['spy_closePrice']
tm_stock = final_df['tm_closePrice']
intc_stock = final_df['intc_closePrice']
amd_stock = final_df['amd_closePrice']
gt_stock = final_df['gt_closePrice']
hmc_stock = final_df['hmc_closePrice']
cpi = final_df['cpi_value']

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of interest rate using seaborn
sns.boxplot(interest_rate, color='azure')

# Add a title
plt.title("Boxplot of Interest Rates")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("Interest Rates")

# Show the plot
plt.show()

# %%
# Z-scores method for interest rates:
# I can calculate the z-scores for each data point and determine if any values fall outside a certain threshold,
# values that are more than a few standard deviations away from the mean can be considered outliers.

# %%
# Calculate the mean, median, and standard deviation for interest rates
mean = interest_rate.mean()
median = interest_rate.median()
std = interest_rate.std()
# Define the threshold for outliers 
# which is set to more than 3 standard deviations away from the mean 
threshold = 3
# Calculate the z-scores for each data point.
# Subtracts the mean from each data point and then divides by the standard deviation to standardize the data.
# Calculating the z-scores, I can determine how far each data point deviates from the mean in terms of standard deviations.
# Positive z-scores indicate values above the mean, while negative z-scores indicate values below the mean.
z_scores = (interest_rate - mean) / std

# Identify the outliers based on the threshold.
# The abs() function is used to take the absolute value of each z-score, 
# ensuring that both positive and negative deviations from the mean are considered.
# The resulting outliers are stored in the outliers variable, 
# which contains the subset of "interest_rate" values that are identified as outliers 
# based on their z-scores exceeding the threshold of 3.
outliers = interest_rate[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# Series([], Name: daily_rate, dtype: float64)

# %%
# There is no outliers for interest rates in the z-scores method and boxplot.

# %%
# Repeat the same for stock market indices

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of stock market index using seaborn
sns.boxplot(stock_market, color='green')

# Add a title
plt.title("Boxplot of Stock Market Index")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("Stock Market Index")

# Show the plot
plt.show()

# %%
# Calculate the mean, median, and standard deviation
mean = stock_market.mean()
median = stock_market.median()
std = stock_market.std()

# Define the threshold for outliers 
threshold = 3

# Calculate the z-scores for each data point
# which is set to more than 3 standard deviations away from the mean 
z_scores = (stock_market - mean) / std

# Identify the outliers based on the threshold
outliers = stock_market[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# Series([], Name: spy_closePrice, dtype: float64)

# %%
# There is no outliers for stock market index in the z-scores method and box plot.

# %%
# Repeat the same for Toyota stock prices

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of Toyota using seaborn
sns.boxplot(tm_stock, color='linen')

# Add a title
plt.title("Boxplot of Toyota Stock Prices")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("Toyota Stock Prices")

# Show the plot
plt.show()

# %%
# Calculate the mean, median, and standard deviation
mean = tm_stock.mean()
median = tm_stock.median()
std = tm_stock.std()

# Define the threshold for outliers 
threshold = 3

# Calculate the z-scores for each data point
# which is set to more than 3 standard deviations away from the mean 
z_scores = (tm_stock - mean) / std

# Identify the outliers based on the threshold
outliers = tm_stock[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# Series([], Name: tm_closePrice, dtype: float64)

# %%
# There is no outliers for Toyota stock prices in the z-scores method and box plot.

# %%
# Repeat the same for Intel stock prices

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of Intel using seaborn
sns.boxplot(intc_stock, color='crimson')

# Add a title
plt.title("Boxplot of Intel Stock Prices")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("Intel Stock Prices")

# Show the plot
plt.show()

# %%
# Calculate the mean, median, and standard deviation
mean = intc_stock.mean()
median = intc_stock.median()
std = intc_stock.std()

# Define the threshold for outliers 
threshold = 3

# Calculate the z-scores for each data point
# which is set to more than 3 standard deviations away from the mean 
z_scores = (intc_stock - mean) / std

# Identify the outliers based on the threshold
outliers = intc_stock[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# Series([], Name: intc_closePrice, dtype: float64)

# %%
# There is no outliers for Intel stock prices in the z-scores method and box plot.

# %%
# Repeat the same for AMD stock prices

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of AMD using seaborn
sns.boxplot(amd_stock, color='orange')

# Add a title
plt.title("Boxplot of AMD Stock Prices")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("AMD Stock Prices")

# Show the plot
plt.show()

# %%
# Calculate the mean, median, and standard deviation
mean = amd_stock.mean()
median = amd_stock.median()
std = amd_stock.std()

# Define the threshold for outliers 
threshold = 3

# Calculate the z-scores for each data point
# which is set to more than 3 standard deviations away from the mean 
z_scores = (amd_stock - mean) / std

# Identify the outliers based on the threshold
outliers = amd_stock[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# Series([], Name: amd_closePrice, dtype: float64)

# %%
# There is no outliers for AMD stock prices in the z-scores method and box plot.

# %%
# Repeat the same for GoodYear Tire stock prices

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of GoodYear Tire using seaborn
sns.boxplot(gt_stock, color='red')

# Add a title
plt.title("Boxplot of GoodYear Stock Prices")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("GoodYear Stock Prices")

# Show the plot
plt.show()

# %%
# Calculate the mean, median, and standard deviation
mean = gt_stock.mean()
median = gt_stock.median()
std = gt_stock.std()

# Define the threshold for outliers 
threshold = 3

# Calculate the z-scores for each data point
# which is set to more than 3 standard deviations away from the mean 
z_scores = (gt_stock - mean) / std

# Identify the outliers based on the threshold
outliers = gt_stock[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# Series([], Name: gt_closePrice, dtype: float64)

# %%
# There is no outliers for GoodYear stock prices in the z-scores method and box plot.

# %%
# Repeat the same for Honda stock prices

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of Honda using seaborn
sns.boxplot(hmc_stock, color='brown')

# Add a title
plt.title("Boxplot of Honda Stock Prices")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("Honda Stock Prices")

# Show the plot
plt.show()

# %%
# Calculate the mean, median, and standard deviation
mean = hmc_stock.mean()
median = hmc_stock.median()
std = hmc_stock.std()

# Define the threshold for outliers 
threshold = 3

# Calculate the z-scores for each data point
# which is set to more than 3 standard deviations away from the mean 
z_scores = (hmc_stock - mean) / std

# Identify the outliers based on the threshold
outliers = hmc_stock[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# 1176    36.669998
# Name: hmc_closePrice, dtype: float64

# %%
# There is one outlier for Honda stock prices in the z-scores method and box plot. 
# I keep it because of no big impact on final dataset.

# %%
# Repeat the same for CPI

# %%
# Import seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of CPI using seaborn
sns.boxplot(cpi, color='yellow')

# Add a title
plt.title("Boxplot of CPI")

# Label the x and y axes
plt.xlabel("Identify Outliers")
plt.ylabel("CPI Values")

# Show the plot
plt.show()

# %%
# Calculate the mean, median, and standard deviation
mean = cpi.mean()
median = cpi.median()
std = cpi.std()

# Define the threshold for outliers 
threshold = 3

# Calculate the z-scores for each data point
# which is set to more than 3 standard deviations away from the mean 
z_scores = (cpi - mean) / std

# Identify the outliers based on the threshold
outliers = cpi[abs(z_scores) > threshold]

# Print the identified outliers
print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
# Series([], Name: cpi_value, dtype: float64)

# %%
# There is no outliers for CPI values in the z-scores method and box plot.

# %% [markdown]
# # Graphical Analysis

# %%
# Import few libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Time Series Plot of Toyota Stock Prices

# %%
# Convert the 'Date' column in the DataFrame 'final_df' to datetime format using the pd.to_datetime() function
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')

# Create a new figure with a specified size using the plt.figure() function from the matplotlib.pyplot library. 
# The figsize parameter determines the width and height of the figure in inches.
plt.figure(figsize=(10, 6))

# Plot a line graph using the 'Date' column as the x-axis and the 'tm_closePrice' column as the y-axis. 
# It visualizes the time series of Toyota stock prices over the specified period, 2019-2024.
plt.plot(final_df['Date'], final_df['tm_closePrice'])

# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['tm_closePrice'], 1)
p = np.poly1d(z)

# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')

# Set the x-axis label of the plot as 'Date'
plt.xlabel('Date')

# Set the y-axis label of the plot as 'Apple Stock Price'
plt.ylabel('Toyota Stock Prices')

# Set the title of the plot as 'Time Series Plot of Apple Stock Prices'
plt.title('Time Series Plot of Toyota Stock Prices')

# Display the plot.
plt.show()

# %%
# I can visualize the historical trends and fluctuations in Toyota stock prices over time. 
# The slope of this plot is positive, indicating an upward trend.
# The plot helps to identify patterns, and overall movements in the stock price, 
# providing insights into the historical performance of Toyota stock performance.

# %% [markdown]
# ### Time Series Plot of Interest Rates

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')
plt.figure(figsize=(10, 6))
plt.plot(final_df['Date'], final_df['daily_rate'])
# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['daily_rate'], 1)
p = np.poly1d(z)
# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')
plt.xlabel('Date')
plt.ylabel('Interest Rate')
plt.title('Time Series Plot of Interest Rates')
plt.show()

# %%
# The Time Series Plot of Interest Rates has a positive slope, indicating an upward trend.

# %% [markdown]
# ### Time Series Plot of Stock Market Indices

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')
plt.figure(figsize=(10, 6))
plt.plot(final_df['Date'], final_df['spy_closePrice'])
# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['spy_closePrice'], 1)
p = np.poly1d(z)
# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')
plt.xlabel('Date')
plt.ylabel('Stock Market Index')
plt.title('Time Series Plot of Stock Market Index')
plt.show()

# %%
# The Time Series Plot of Stock Market Index has a positive slope, indicating an upward trend.

# %% [markdown]
# ### Time Series Plot of Intel Stock Prices

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')
plt.figure(figsize=(10, 6))
plt.plot(final_df['Date'], final_df['intc_closePrice'])
# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['intc_closePrice'], 1)
p = np.poly1d(z)
# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')
plt.xlabel('Date')
plt.ylabel('Intel Stock Prices')
plt.title('Time Series Plot of Intel Stock Prices')
plt.show()

# %%
# The Time Series Plot of Intel Stock Prices has a negative slope, indicating a downward trend.

# %% [markdown]
# ### Time Series Plot of AMD Stock Prices

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')
plt.figure(figsize=(10, 6))
plt.plot(final_df['Date'], final_df['amd_closePrice'])
# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['amd_closePrice'], 1)
p = np.poly1d(z)
# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')
plt.xlabel('Date')
plt.ylabel('AMD Stock Prices')
plt.title('Time Series Plot of AMD Stock Prices')
plt.show()

# %%
# The Time Series Plot of AMD Stock Prices has a positive slope, indicating an upward trend.

# %% [markdown]
# ### Time Series Plot of GoodYear Tire Stock Prices

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')
plt.figure(figsize=(10, 6))
plt.plot(final_df['Date'], final_df['gt_closePrice'])
# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['gt_closePrice'], 1)
p = np.poly1d(z)
# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')
plt.xlabel('Date')
plt.ylabel('GoodYear Tire Stock Prices')
plt.title('Time Series Plot of GoodYear Tire Stock Prices')
plt.show()

# %%
# The Time Series Plot of GoodYear Tire Stock Prices has a negative slope, indicating a downward trend.

# %% [markdown]
# ### Time Series Plot of Honda Stock Prices

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')
plt.figure(figsize=(10, 6))
plt.plot(final_df['Date'], final_df['hmc_closePrice'])
# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['hmc_closePrice'], 1)
p = np.poly1d(z)
# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')
plt.xlabel('Date')
plt.ylabel('Honda Stock Prices')
plt.title('Time Series Plot of Honda Stock Prices')
plt.show()

# %%
# The Time Series Plot of Honda Stock Prices has a positive slope, indicating an upward trend.

# %% [markdown]
# ### Time Series Plot of CPI values

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'], unit='ns')
plt.figure(figsize=(10, 6))
plt.plot(final_df['Date'], final_df['cpi_value'])
# Calculate the slope
z = np.polyfit(range(len(final_df)), final_df['cpi_value'], 1)
p = np.poly1d(z)
# Plot the slope
plt.plot(final_df['Date'], p(range(len(final_df))), linestyle='--', color='red')
plt.xlabel('Date')
plt.ylabel('CPI Values')
plt.title('Time Series Plot of CPI Values')
plt.show()

# %%
# The Time Series Plot of CPI values has a positive slope, indicating an upward trend.

# %% [markdown]
# ### Correlation Heatmap

# %%
# List column names
final_df.columns
# Out:
# Index(['tm_closePrice', 'tm_point_change', 'tm_Indication', 'spy_closePrice',
#        'intc_closePrice', 'amd_closePrice', 'gt_closePrice', 'hmc_closePrice',
#        'cpi_value', 'Date', 'Id', 'daily_rate', '1 Mo', '2 Mo', '3 Mo', '6 Mo',
#        '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr',
#        'spy_OpenPrice', 'spy_HighPrice', 'spy_LowPrice', 'spy_volumn',
#        'tm_volumn', 'tm_OpenPrice', 'tm_HighPrice', 'tm_lowPrice',
#        'intc_OpenPrice', 'intc_HighPrice', 'intc_LowPrice', 'intc_volumn',
#        'amd_OpenPrice', 'amd_HighPrice', 'amd_LowPrice', 'amd_volumn',
#        'gt_OpenPrice', 'gt_HighPrice', 'gt_LowPrice', 'gt_volumn',
#        'hmc_OpenPrice', 'hmc_HighPrice', 'hmc_LowPrice', 'hmc_volumn'],
#       dtype='object')

# %%
# Calculate the correlation matrix between the columns in the 'final_df'. 
# The corr() function calculates the pairwise correlation coefficients between the selected columns.
correlation_matrix = final_df[['tm_closePrice', 'spy_closePrice', 'intc_closePrice','amd_closePrice','gt_closePrice','hmc_closePrice','cpi_value','daily_rate']].corr()

# Create a heatmap using the seaborn library (sns). 
# The heatmap() function is used to plot the correlation matrix as a colored grid, 
# where the colors represent the strength and direction of the correlation. 
# The annot=True parameter displays the correlation coefficients on the heatmap.
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Set the title of the heatmap as 'Correlation Heatmap'.
plt.title('Correlation Heatmap')
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
# The heatmap helps to identify the relationships and dependencies between these variables. 
# Positive correlations are indicated by red/light red color, while negative correlations are indicated by blue/light blue color. 
# The correlation coefficients displayed on the heatmap provide a numerical measure of the strength and direction of the correlations.

# The correlation between Toyota and SPY is positive, meaning, as the Toyota increases, the SPY increases.
# The correlation between Toyota and Intel is negative, meaning, as the Toyota increases, the Intel decreases.
# The correlation between Toyota and AMD is positive, meaning, as the Toyota increases, the AMD increases.
# The correlation between Toyota and GoodYear is positive, meaning, as the Toyota increases, the GoodYear increases.
# The correlation between Toyota and Honda is positive, meaning, as the Toyota increases, the Honda increases.
# The correlation between Toyota and CPI is positive, meaning, as the Toyota increases, the CPI increases.
# The correlation between Toyota and Rate is positive, meaning, as the Toyota increases, the Rate increases.

# %% [markdown]
# ### Scatter Plot Toyota Vs. S&P500 index

# %%
# Subset the data for the variables of interest rate, stock market indices, Toyota stock prices,
# Intel stock prices, AMD stock prices, GoodYear stock prices, Honda stock prices, and CPI values
interest_rate = final_df['daily_rate']
stock_market = final_df['spy_closePrice']
tm = final_df['tm_closePrice']
intc = final_df['intc_closePrice']
amd = final_df['amd_closePrice']
gt= final_df['gt_closePrice']
hmc = final_df['hmc_closePrice']
cpi = final_df['cpi_value']

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Toyota Vs. stock market index scatter plot
# Toyota represents the x-axis values, and stock_market represents the y-axis values. 
# Each data point is represented as a single point on the plot, 
# where the x-coordinate corresponds to the Toyota, and the y-coordinate corresponds to the S&P 500 index price.
plt.scatter(tm, stock_market, color='g')
# Set the label for the x-axis as "Toyota stock prices"
plt.xlabel('Toyota Stock Prices')
# Set the label for the y-axis as "S&P 500 Index Price."
plt.ylabel('S&P 500 Index Prices')
# Set the title of the scatter plot as "Toyota vs. S&P 500 Index Price."
plt.title('Toyota Stock Prices vs. S&P 500 Index Prices')
# Display the plot
plt.show()

# %% [markdown]
# ### Scatter Plot Toyota Vs. Interest Rate

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Toyota Vs. Interest Rate scatter plot
# Toyota represents the x-axis values, and Interest Rate represents the y-axis values. 
# Each data point is represented as a single point on the plot, 
# where the x-coordinate corresponds to the Toyota, and the y-coordinate corresponds to the Interest Rate.
plt.scatter(tm, interest_rate, color='b')
# Set the label for the x-axis as "Toyota stock prices"
plt.xlabel('Toyota Stock Prices')
# Set the label for the y-axis as "Interest Rate."
plt.ylabel('Interest Rate')
# Set the title of the scatter plot as "Toyota vs. Interest Rate."
plt.title('Toyota Stock Prices vs. Interest Rate')
# Display the plot
plt.show()

# %% [markdown]
# ### Scatter Plot Toyota Vs. Intel

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Toyota Vs. Intel scatter plot
# Toyota represents the x-axis values, and Intel represents the y-axis values. 
# Each data point is represented as a single point on the plot, 
# where the x-coordinate corresponds to the Toyota, and the y-coordinate corresponds to the Intel.
plt.scatter(tm, intc, color='orange')
# Set the label for the x-axis as "Toyota stock prices"
plt.xlabel('Toyota Stock Prices')
# Set the label for the y-axis as "Intel"
plt.ylabel('Intel Stock Prices')
# Set the title of the scatter plot as "Toyota vs. Intel."
plt.title('Toyota Stock Prices vs. Intel Stock Prices')
# Display the plot
plt.show()

# %% [markdown]
# ### Scatter Plot Toyota Vs. AMD

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Toyota Vs. AMD scatter plot
# Toyota represents the x-axis values, and AMD represents the y-axis values. 
# Each data point is represented as a single point on the plot, 
# where the x-coordinate corresponds to the Toyota, and the y-coordinate corresponds to the AMD.
plt.scatter(tm, amd, color='red')
# Set the label for the x-axis as "Toyota stock prices"
plt.xlabel('Toyota Stock Prices')
# Set the label for the y-axis as "AMD"
plt.ylabel('AMD Stock Prices')
# Set the title of the scatter plot as "Toyota vs. AMD."
plt.title('Toyota Stock Prices vs. AMD Stock Prices')
# Display the plot
plt.show()

# %% [markdown]
# ### Scatter Plot Toyota Vs. GoodYear

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Toyota Vs. GoodYear scatter plot
# Toyota represents the x-axis values, and GoodYear represents the y-axis values. 
# Each data point is represented as a single point on the plot, 
# where the x-coordinate corresponds to the Toyota, and the y-coordinate corresponds to the GoodYear.
plt.scatter(tm, gt, color='brown')
# Set the label for the x-axis as "Toyota stock prices"
plt.xlabel('Toyota Stock Prices')
# Set the label for the y-axis as "GoodYear"
plt.ylabel('GoodYear Stock Prices')
# Set the title of the scatter plot as "Toyota vs. GoodYear."
plt.title('Toyota Stock Prices vs. GoodYear Stock Prices')
# Display the plot
plt.show()

# %% [markdown]
# ### Scatter Plot Toyota Vs. Honda

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Toyota Vs. Honda scatter plot
# Toyota represents the x-axis values, and Honda represents the y-axis values. 
# Each data point is represented as a single point on the plot, 
# where the x-coordinate corresponds to the Toyota, and the y-coordinate corresponds to the Honda
plt.scatter(tm, hmc, color='gold')
# Set the label for the x-axis as "Toyota stock prices"
plt.xlabel('Toyota Stock Prices')
# Set the label for the y-axis as "Honda"
plt.ylabel('Honda Stock Prices')
# Set the title of the scatter plot as "Toyota vs. AMD."
plt.title('Toyota Stock Prices vs. Honda Stock Prices')
# Display the plot
plt.show()

# %% [markdown]
# ### Scatter Plot Toyota Vs. CPI

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Toyota Vs. CPI scatter plot
# Toyota represents the x-axis values, and CPI represents the y-axis values. 
# Each data point is represented as a single point on the plot, 
# where the x-coordinate corresponds to the Toyota, and the y-coordinate corresponds to the CPI.
plt.scatter(tm, cpi, color='chocolate')
# Set the label for the x-axis as "Toyota stock prices"
plt.xlabel('Toyota Stock Prices')
# Set the label for the y-axis as "CPI"
plt.ylabel('CPI Values')
# Set the title of the scatter plot as "Toyota vs. AMD."
plt.title('Toyota Stock Prices vs. CPI values')
# Display the plot
plt.show()

# %% [markdown]
# ### Analyze their relationships

# %%
# Import few libraries
import pandas as pd
import numpy as np

# Calculate the covariance and Pearson's correlation coefficients for the two pairs of variables.

# This line calculates the covariance between the Toyota and stock_market variables using the cov() function from NumPy. 
# The cov() function returns a covariance matrix, and I select the value at index [0][1] to obtain the covariance between the two variables.
tm_stock_cov = np.cov(tm, stock_market)[0][1]

# This line calculates the Pearson's correlation coefficient between the Toyota and stock_market variables 
# using the corrcoef() function from NumPy. 
# The corrcoef() function returns a correlation matrix, and I select the value at index [0][1] to obtain the correlation coefficient between the two variables.
tm_stock_corr = np.corrcoef(tm, stock_market)[0][1]

# This line calculates the covariance between the Toyota and Intel variables in the same way as explained above.
tm_intc_cov = np.cov(tm, intc)[0][1]

# This line calculates the Pearson's correlation coefficient between the Toyota and 
# Intel variables in the same way as explained above.
tm_intc_corr = np.corrcoef(tm, intc)[0][1]

# This line calculates the covariance between the Toyota and interest_rate variables in the same way as explained above.
tm_rate_cov = np.cov(tm, interest_rate)[0][1]

# This line calculates the Pearson's correlation coefficient between the Toyota and 
# interest_rate in the same way as explained above.
tm_rate_corr = np.corrcoef(tm, interest_rate)[0][1]

# This line calculates the covariance between the Toyota and AMD variables in the same way as explained above.
tm_amd_cov = np.cov(tm, amd)[0][1]

# This line calculates the Pearson's correlation coefficient between the Toyota and 
# AMD variables in the same way as explained above.
tm_amd_corr = np.corrcoef(tm, amd)[0][1]

# This line calculates the covariance between the Toyota and GoodYear variables in the same way as explained above.
tm_gt_cov = np.cov(tm, gt)[0][1]

# This line calculates the Pearson's correlation coefficient between the Toyota and 
# GoodYear variables in the same way as explained above.
tm_gt_corr = np.corrcoef(tm, gt)[0][1]

# This line calculates the covariance between the Toyota and Honda variables in the same way as explained above.
tm_hmc_cov = np.cov(tm, hmc)[0][1]

# This line calculates the Pearson's correlation coefficient between the Toyota and 
# Honda variables in the same way as explained above.
tm_hmc_corr = np.corrcoef(tm, hmc)[0][1]

# This line calculates the covariance between the Toyota and CPI variables in the same way as explained above.
tm_cpi_cov = np.cov(tm, cpi)[0][1]

# This line calculates the Pearson's correlation coefficient between the Toyota and 
# CPI variables in the same way as explained above.
tm_cpi_corr = np.corrcoef(tm, cpi)[0][1]

# Print the covariance and Pearson's correlation coefficients
print(f'Toyota and Stock Market Index: Covariance = {tm_stock_cov:.2f}, Pearson\'s Correlation = {tm_stock_corr:.2f}')
print(f'Toyota and Interest rate: Covariance = {tm_rate_cov:.2f}, Pearson\'s Correlation = {tm_rate_corr:.2f}')
print(f'Toyota and Intel: Covariance = {tm_intc_cov:.2f}, Pearson\'s Correlation = {tm_intc_corr:.2f}')
print(f'Toyota and AMD: Covariance = {tm_amd_cov:.2f}, Pearson\'s Correlation = {tm_amd_corr:.2f}')
print(f'Toyota and GoodYear: Covariance = {tm_gt_cov:.2f}, Pearson\'s Correlation = {tm_gt_corr:.2f}')
print(f'Toyota and Honda: Covariance = {tm_hmc_cov:.2f}, Pearson\'s Correlation = {tm_hmc_corr:.2f}')
print(f'Toyota and CPI: Covariance = {tm_cpi_cov:.2f}, Pearson\'s Correlation = {tm_cpi_corr:.2f}')
# Out:
# Toyota and Stock Market Index: Covariance = 1231.78, Pearson's Correlation = 0.88
# Toyota and Interest rate: Covariance = 1.70, Pearson's Correlation = 0.04
# Toyota and Intel: Covariance = -12.37, Pearson's Correlation = -0.05
# Toyota and AMD: Covariance = 600.90, Pearson's Correlation = 0.82
# Toyota and GoodYear: Covariance = 35.72, Pearson's Correlation = 0.42
# Toyota and Honda: Covariance = 44.16, Pearson's Correlation = 0.67
# Toyota and CPI: Covariance = 227.43, Pearson's Correlation = 0.53

# %%
# Covariance measures the linear relationship between two variables and provides information about 
# the direction and magnitude of their association. A positive covariance indicates a positive relationship, 
# while a negative covariance indicates a negative relationship.

# Pearson's correlation coefficient is a standardized measure of the linear relationship between two variables. 
# It ranges from -1 to +1, with values closer to +1 indicating a strong positive correlation, 
# values closer to -1 indicating a strong negative correlation, 
# and values close to 0 indicating little or no linear correlation.

# Analyzing the scatter plots, I can gain insights into the correlation and potential causation between the two variables.

# 1st scatter plot: I can see that there is a strong positive correlation between Toyota and the stock market index. 
# As stock market index increases, the Toyota tends to increase.

# 2nd scatter plot: I can see that there is a weak positive correlation of 0.04 between Toyota and Interest Rate.
# It suggests a very weak positive linear relationship, almost no relationship at all.

# 3rd scatter plot: I can see that there is a weak negative linear relationship between Toyota and Intel.
# meaning that as one variable increases, the other tends to decrease, but the relationship is not strong.

# 4th scatter plot: I can see that there is a strong positive correlation between Toyota and the AMD. 
# As AMD increases, the Toyota tends to increase.

# 5th scatter plot: I can see that there is a moderate positive correlation between Toyota and the GoodYear Tire. 
# As GoodYear Tire increases, the Toyota tends to increase, but the relationship is not as strong as in the case of the AMD.

# 6th scatter plot: I can see that there is a moderate positive correlation between Toyota and the Honda. 
# As Honda increases, the Toyota tends to increase.

# 7th scatter plot: I can see that there is a moderate positive correlation between Toyota and CPI. 
# As CPI increases, the Toyota tends to increase.

# %% [markdown]
# # Drop any features that are not useful.

# %%
# Show few rows
final_df.head()
# Out:
#    tm_closePrice  tm_point_change tm_Indication  spy_closePrice  \
# 0     116.279999         1.629997        Up-day      250.179993
# 1     114.650002        -5.080002      Down-day      244.210007
# 2     119.730003        -1.549995      Down-day      252.389999
# 3     121.279999        -1.029999      Down-day      254.380005
# 4     122.309998        -0.610001      Down-day      256.769989
#
#    intc_closePrice  amd_closePrice  gt_closePrice  hmc_closePrice  cpi_value  \
# 0        47.080002       18.830000      20.670000       26.480000    251.712
# 1        44.490002       17.049999      20.309999       26.120001    251.712
# 2        47.220001       19.000000      21.180000       27.309999    251.712
# 3        47.439999       20.570000      21.000000       27.820000    251.712
# 4        47.740002       20.750000      21.059999       28.480000    251.712
#
#         Date  ...  amd_LowPrice  amd_volumn  gt_OpenPrice  gt_HighPrice  \
# ...

# %%
# List the column names
final_df.columns
# Out:
# Index(['tm_closePrice', 'tm_point_change', 'tm_Indication', 'spy_closePrice',
#        'intc_closePrice', 'amd_closePrice', 'gt_closePrice', 'hmc_closePrice',
#        'cpi_value', 'Date', 'Id', 'daily_rate', '1 Mo', '2 Mo', '3 Mo', '6 Mo',
#        '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr',
#        'spy_OpenPrice', 'spy_HighPrice', 'spy_LowPrice', 'spy_volumn',
#        'tm_volumn', 'tm_OpenPrice', 'tm_HighPrice', 'tm_lowPrice',
#        'intc_OpenPrice', 'intc_HighPrice', 'intc_LowPrice', 'intc_volumn',
#        'amd_OpenPrice', 'amd_HighPrice', 'amd_LowPrice', 'amd_volumn',
#        'gt_OpenPrice', 'gt_HighPrice', 'gt_LowPrice', 'gt_volumn',
#        'hmc_OpenPrice', 'hmc_HighPrice', 'hmc_LowPrice', 'hmc_volumn'],
#       dtype='object')

# %%
# I would drop the following features:

# 1.Date: Since I have already used the 'Date' feature to plot the time series. I may not need it for model building.

# 2.Id: It does not provide any meaningful information related to the target variable or the other features.

# 3.'1 Mo', '2 Mo', '3 Mo', '6 Mo', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr': 
# While interest rates can influence stock prices, including all these features can lead to a high-dimensional dataset, 
# making the model more complex without necessarily adding substantial predictive power.

# 4.'spy_OpenPrice', 'spy_HighPrice', 'spy_LowPrice', 'spy_volumn', 'tm_volumn', 'tm_OpenPrice', 
# 'tm_HighPrice', 'tm_lowPrice', 'intc_OpenPrice', 'intc_HighPrice','intc_LowPrice', 'intc_volumn', 
# 'amd_OpenPrice', 'amd_HighPrice', 'amd_LowPrice', 'amd_volumn',
# 'gt_OpenPrice', 'gt_HighPrice', 'gt_LowPrice', 'gt_volumn',
# 'hmc_OpenPrice', 'hmc_HighPrice', 'hmc_LowPrice', 'hmc_volumn',

# These features might have some impact on stock prices, 
# but they are unlikely to be major drivers. 

# Drop the unnecessary features
final_df.drop(['Date', 'Id', 'spy_OpenPrice', 'spy_HighPrice', 'spy_LowPrice', 'spy_volumn', 'tm_volumn', 'tm_OpenPrice', 
'tm_HighPrice', 'tm_lowPrice', 'intc_OpenPrice', 'intc_HighPrice','intc_LowPrice', 'intc_volumn', 
'amd_OpenPrice', 'amd_HighPrice', 'amd_LowPrice', 'amd_volumn',
'gt_OpenPrice', 'gt_HighPrice', 'gt_LowPrice', 'gt_volumn',
'hmc_OpenPrice', 'hmc_HighPrice', 'hmc_LowPrice', 'hmc_volumn',
'1 Mo', '2 Mo', '3 Mo', '6 Mo', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr'],axis=1, inplace=True)

# %%
# Show few rows
final_df.head()
# Out:
#    tm_closePrice  tm_point_change tm_Indication  spy_closePrice  \
# 0     116.279999         1.629997        Up-day      250.179993
# 1     114.650002        -5.080002      Down-day      244.210007
# 2     119.730003        -1.549995      Down-day      252.389999
# 3     121.279999        -1.029999      Down-day      254.380005
# 4     122.309998        -0.610001      Down-day      256.769989
#
#    intc_closePrice  amd_closePrice  gt_closePrice  hmc_closePrice  cpi_value  \
# 0        47.080002       18.830000      20.670000       26.480000    251.712
# 1        44.490002       17.049999      20.309999       26.120001    251.712
# 2        47.220001       19.000000      21.180000       27.309999    251.712
# 3        47.439999       20.570000      21.000000       27.820000    251.712
# 4        47.740002       20.750000      21.059999       28.480000    251.712
#
#    daily_rate
# 0        2.60
# 1        2.50
# 2        2.57
# 3        2.58
# 4        2.60

# %% [markdown]
# # Convert categorial column to numeric column

# %%
# Display the unique values in the aapl_Indication column
final_df['tm_Indication'].unique()
# Out:
# array(['Up-day', 'Down-day'], dtype=object)

# %%
# final_df['tm_Indication']: This selects the column named 'tm_Indication' from the DataFrame final_df.
# .map({'Up-day': 0, 'Down-day': 1}): The map() method is applied to the selected column. 
# It takes a dictionary as an argument, where keys are the original categorical values, 
# and values are the corresponding numerical values that I want to replace with. 
# In this case, it converts 'Up-day' to 0 and 'Down-day' to 1.
final_df['tm_Indication'] = final_df['tm_Indication'].map({'Up-day':0,'Down-day':1})

# %%
# Show few rows
final_df.head()
# Out:
#    tm_closePrice  tm_point_change  tm_Indication  spy_closePrice  \
# 0     116.279999         1.629997              0      250.179993
# 1     114.650002        -5.080002              1      244.210007
# 2     119.730003        -1.549995              1      252.389999
# 3     121.279999        -1.029999              1      254.380005
# 4     122.309998        -0.610001              1      256.769989
#
#    intc_closePrice  amd_closePrice  gt_closePrice  hmc_closePrice  cpi_value  \
# 0        47.080002       18.830000      20.670000       26.480000    251.712
# 1        44.490002       17.049999      20.309999       26.120001    251.712
# 2        47.220001       19.000000      21.180000       27.309999    251.712
# 3        47.439999       20.570000      21.000000       27.820000    251.712
# 4        47.740002       20.750000      21.059999       28.480000    251.712
#
#    daily_rate
# 0        2.60
# 1        2.50
# 2        2.57
# 3        2.58
# 4        2.60

# %% [markdown]
# # Store feature Matrix in X and Response (target) in vector y

# %%
# List the column names
final_df.columns
# Out:
# Index(['tm_closePrice', 'tm_point_change', 'tm_Indication', 'spy_closePrice',
#        'intc_closePrice', 'amd_closePrice', 'gt_closePrice', 'hmc_closePrice',
#        'cpi_value', 'daily_rate'],
#       dtype='object')

# %%
# The drop() method in Pandas is used to remove columns from a DataFrame. 
# In this case, it drops the column named 'tm_closePrice' from the DataFrame final_df. 
# The parameter axis=1 indicates that I want to drop a column 
# Assign the resulting DataFrame after dropping the column 'tm_closePrice' to the variable X. 
# X now contains all the features (independent variables) for the machine learning model.
X=final_df.drop(['tm_closePrice'], axis=1)

# Display the independent features
X
# Out:
#       tm_point_change  tm_Indication  spy_closePrice  intc_closePrice  \
# 0            1.629997              0      250.179993        47.080002
# 1           -5.080002              1      244.210007        44.490002
# 2           -1.549995              1      252.389999        47.220001
# 3           -1.029999              1      254.380005        47.439999
# 4           -0.610001              1      256.769989        47.740002
# ...               ...            ...             ...              ...
# 1241         2.330002              0      472.700012        47.080002
# 1242        -1.320007              1      473.649994        48.000000
# 1243        -0.869995              1      475.649994        50.500000
# 1244        -0.389999              1      476.510010        50.759998
# 1245        -2.270004              1      476.690002        50.389999
#
#       amd_closePrice  gt_closePrice  hmc_closePrice  cpi_value  daily_rate
# ...

# %%
# Select the target variable (or dependent variable) 'tm_closePrice' from the DataFrame final_df.
y = final_df['tm_closePrice']

# Display the dependent target
y
# Out:
# 0       116.279999
# 1       114.650002
# 2       119.730003
# 3       121.279999
# 4       122.309998
#            ...
# 1241    180.860001
# 1242    178.529999
# 1243    179.850006
# 1244    180.720001
# 1245    181.110001
# Name: tm_closePrice, Length: 1246, dtype: float64

# %% [markdown]
# # Normalization

# %%
# Import MinMaxScaler for scaling numerical features
from sklearn.preprocessing import MinMaxScaler

# Create an instance of the MinMaxScaler class, which will be used to perform feature scaling.
sc = MinMaxScaler()
# scaler.fit_transform(...): The fit_transform method of the MinMaxScaler class is used to perform feature scaling 
# on the independent features. 
# The fit_transform method first fits the scaler to the data to compute the minimum and maximum values for each feature, 
# and then it transforms the data using the computed minimum and maximum values to scale the data.
scaling_X = sc.fit_transform(X)
# Show feature scaling
scaling_X
# Out:
# array([[0.61856102, 0.        , 0.1068849 , ..., 0.3938132 , 0.        ,
#         0.46972477],
#        [0.33290775, 1.        , 0.08345113, ..., 0.37239745, 0.        ,
#         0.45137615],
#        [0.48318465, 1.        , 0.11555975, ..., 0.44318857, 0.        ,
#         0.46422018],
#        ...,
#        [0.51213313, 1.        , 0.99191397, ..., 0.63890549, 0.98140057,
#         0.87889908],
#        [0.53256717, 1.        , 0.99528976, ..., 0.63355153, 0.98140057,
#         0.87155963],
#        [0.45253295, 1.        , 0.99599627, ..., 0.64187987, 0.98140057,
#         0.87706422]])

# %%
import numpy as np

# Repeat the same for the dependent feature
sc1 = MinMaxScaler()
y_reshape = y.values.reshape(-1,1)
scaling_y = sc1.fit_transform(y_reshape)
scaling_y = np.ravel(scaling_y)
scaling_y
# Out:
# array([0.07562943, 0.05978421, 0.10916695, ..., 0.69359395, 0.70205118,
#        0.70584236])

# %% [markdown]
# # Splitting the dataset into the training and testing set

# %%
# Import the train_test_split function from the scikit-learn library. 
# The train_test_split function is used to split datasets into training and testing subsets.
from sklearn.model_selection import train_test_split

# Call the train_test_split function and performs the dataset split.
# X: This is the feature matrix containing all the independent variables.
# y: This is the target variable, which contains the dependent variable to be predicted.
# test_size=0.2: 20% of the data will be used for testing, and 80% will be used for training.
# random_state=42: This parameter sets the random seed for reproducibility
# X_train: This is the feature matrix for training, containing 80% of the data.
# X_test: This is the feature matrix for testing, containing 20% of the data.
# y_train: This is the target variable for training, corresponding to the 80% of the data used for training.
# y_test: This is the target variable for testing, corresponding to the 20% of the data used for testing.
X_train,X_test,y_train,y_test = train_test_split(scaling_X, scaling_y, test_size = 0.2, random_state=42)

# %% [markdown]
# # Import Models

# %%
# Import the LinearRegression class from the scikit-learn library. 
# LinearRegression is a simple and commonly used linear regression model. 
# It fits a linear equation to the input features to predict the target variable.
from sklearn.linear_model import LinearRegression

# Import the SVR class from the scikit-learn library. 
# SVR stands for Support Vector Regressor. 
# It is a regression model based on Support Vector Machines (SVM) that can handle non-linear relationships by using kernels to transform the data into higher dimensions.
from sklearn.svm import SVR

# Import the RandomForestRegressor class from the scikit-learn library. 
# RandomForestRegressor is an ensemble model based on decision trees. 
from sklearn.ensemble import RandomForestRegressor

# Import the XGBoost from scikit-Learn library
# XGB is a powerful machine learning algorithm used for regression tasks like regression and forecasting.
# It is based on gradient boosting, and known for its effectiveness in predicting continuous numeric values.
from xgboost import XGBRegressor

# Import the GradientBoostingRegressor class from the scikit-learn library. 
# GradientBoostingRegressor is another ensemble model that combines multiple weak learners (usually decision trees) in a sequential manner to build a strong predictive model.
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# # Model Training

# %%
# Create an instance of the LinearRegression class and assigns it to the variable lr.
lr = LinearRegression()
# Fit the LinearRegression model to the training data. 
# The fit() method takes the feature matrix X_train and the target variable y_train as inputs and trains the linear regression model using the provided data.
lr.fit(X_train,y_train)

# Create an instance of the SVR class and assigns it to the variable svm.
# The SVR class represents a Support Vector Regressor, which is a type of Support Vector Machine (SVM) used for regression tasks.
svm = SVR()
# Fit the SVR model to the training data. 
# The fit() method takes the feature matrix X_train and the target variable y_train as inputs and trains the Support Vector Regressor model using the provided data.
svm.fit(X_train,y_train)

# Create an instance of the RandomForestRegressor class and assigns it to the variable rf
rf = RandomForestRegressor()
# fFt the RandomForestRegressor model to the training data. 
# The fit() method takes the feature matrix X_train and the target variable y_train as inputs and trains the Random Forest Regressor model using the provided data.
rf.fit(X_train, y_train)

# Create an instance of the XGBoostingRegressor class and assigns it to the variable xgb.
xgb = XGBRegressor()
# Fit the XGBoostingRegressor model to the training data. 
# The fit() method takes the feature matrix X_train and the target variable y_train as inputs and trains the XGBoosting Regressor model using the provided data.
xgb.fit(X_train, y_train)

# Create an instance of the GradientBoostingRegressor class and assigns it to the variable gbr.
gbr = GradientBoostingRegressor()
# Fit the GradientBoostingRegressor model to the training data. 
# The fit() method takes the feature matrix X_train and the target variable y_train as inputs and trains the Gradient Boosting Regressor model using the provided data.
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
# I want to add one more model such as ANN (Artificial Neural Network)

# %%
# Build the ANN, Inputlayers = number of features

# %%
# Import few libraries
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

# Initialize the ANN
ann = Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\henry\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\henry\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Adding input layer and first hidden layer

# %%
ann.add(Dense(81, input_dim=9, activation='relu'))

# %%
# Adding second hidden layer

# %%
ann.add(Dense(81,activation='relu'))

# %%
# Adding the output layer

# %%
ann.add(Dense(1,activation='linear'))

# %%
# Train the ANN

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 81)                810
#
#  dense_1 (Dense)             (None, 81)                6642
#
#  dense_2 (Dense)             (None, 1)                 82
#
# ...
# Total params: 7534 (29.43 KB)
# Trainable params: 7534 (29.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
ann.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\henry\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
ann.fit(X_train, y_train, epochs=100, batch_size = 50, verbose=1,validation_split = .2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\henry\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 16/16 [==============================] - 1s 9ms/step - loss: 0.0515 - val_loss: 0.0181
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0107
# Epoch 3/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 5/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 6/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 7/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 8/100
# ...

# %% [markdown]
# # Prediction on Test data

# %%
# Use the trained linear regression model (lr) to make predictions on the test data X_test. 
# The predict() method of the LinearRegression class takes the test data as input and 
# returns the predicted target variable values (y_pred_lr) based on the learned linear relationship between the features and the target variable.
y_pred_lr = lr.predict(X_test)

# Use the trained Support Vector Regressor model (svm) to make predictions on the test data X_test. 
# The predict() method of the SVR class takes the test data as input and returns the predicted target variable values 
# (y_pred_svm) based on the learned relationship using Support Vector Regression.
y_pred_svm = svm.predict(X_test)

# Use the trained Random Forest Regressor model (rf) to make predictions on the test data X_test. 
# The predict() method of the RandomForestRegressor class takes the test data as input and returns 
# the predicted target variable values (y_pred_rf) based on the ensemble of decision trees learned during training.
y_pred_rf = rf.predict(X_test)

# Use the trained Gradient Boosting Regressor model (gbr) to make predictions on the test data X_test. 
# The predict() method of the GradientBoostingRegressor class takes the test data as input and returns 
# the predicted target variable values (y_pred_gbr) based on the ensemble of weak learners learned in a sequential manner during training.
y_pred_gbr = gbr.predict(X_test)

# Use the trained XGBoosting Regressor model (xgb) to make predictions on the test data X_test. 
# The predict() method of the XGBoostingRegressor class takes the test data as input and returns 
# the predicted target variable values (y_pred_xgb) based on the ensemble of XGBoosting.
y_pred_xgb = xgb.predict(X_test)

# Use the trained ANN model (ann) to make predictions on the test data X_test. 
# The predict() method of the ANN class takes the test data as input and returns 
# the predicted target variable values (y_pred_ann).
y_pred_ann = ann.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 1ms/step

# %% [markdown]
# # Evaluating the algorithm

# %%
# Import the metrics module from scikit-learn. 
from sklearn import metrics

# Calculate the R-squared (R2) score for the first regression(LR) model's predictions (y_pred_lr) compared to the actual target values (y_test). 
# The r2_score() function from the metrics module takes two arguments: the actual target values (y_test) and the predicted target values from the model (y_pred_lr). 
# It then returns the R2 score, which is a value between -1 and 1. 
# R2 score of 1 indicates that the model perfectly fits the data, 
# 0 indicates that the model's predictions are no better than guessing the mean of the target values, 
# and negative values indicate that the model's predictions are worse than guessing the mean.
score_lr = metrics.r2_score(y_test, y_pred_lr)

# Repeat the same for the second regression(SVM)
score_svm = metrics.r2_score(y_test, y_pred_svm)

# Repeat the same for the third regression(RF)
score_rf = metrics.r2_score(y_test, y_pred_rf)

# Repeat the same for the fourth regression(GB)
score_gbr = metrics.r2_score(y_test, y_pred_gbr)

# Repeat the same for the fifth regression(XGB)
score_xgb = metrics.r2_score(y_test, y_pred_xgb)

# Repeat the same for the sixth model(ANN)
score_ann = metrics.r2_score(y_test, y_pred_ann)

# %%
print(score_lr,score_svm,score_rf,score_gbr,score_xgb,score_ann)
# Out:
# 0.8688060516698632 0.9287504616213665 0.9858946998869474 0.9808391216204397 0.9842721878579245 0.9614779542052472

# %%
# Create a new Pandas DataFrame named df that contains multiple models and 
# the R2_score values from each model.

df = pd.DataFrame({'Models':['LR','SVR','RF','GBR','XGB','ANN'], 
                   'R2_score':[score_lr,score_svm,score_rf,score_gbr,score_xgb,score_ann]})

# %%
df
# Out:
#   Models  R2_score
# 0     LR  0.868806
# 1    SVR  0.928750
# 2     RF  0.985895
# 3    GBR  0.980839
# 4    XGB  0.984272
# 5    ANN  0.961478

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df contains your data
sns.set(style="whitegrid")  # Set the style of the plot

# Create the bar plot
ax = sns.barplot(x='R2_score', y='Models', data=df)

# Adding labels and title
plt.xlabel('R-squared (R2) Score')
plt.ylabel('Models')
plt.title('R2 Score Comparison for Different Models')

# Add text labels for each bar
for index, row in df.iterrows():
    ax.text(row['R2_score'], index, f'{row["R2_score"]:.3f}', va='center')

# Display the plot
plt.show()

# %%
# RF is the best performing model which has the highest R2 score, 98.6%.

# %%
# Using mean absolute error

# %%
# Calculate the Mean Absolute Error (MAE) for the first regression(LR) model's predictions (y_pred_lr) compared to the actual target values (y_test). 
# The mean_absolute_error() function from the metrics module takes two arguments: the actual target values (y_test) and the predicted target values from the model (y_pred_lr). 
# It then returns the MAE, which is the average absolute difference between the actual target values and the predicted target values. 
# MAE measures the average magnitude of errors, regardless of their direction.
s_lr = metrics.mean_absolute_error(y_test, y_pred_lr)

# Repeat the same for the second regression(SVM)
s_svm = metrics.mean_absolute_error(y_test, y_pred_svm)

# Repeat the same for the third regression(RF)
s_rf = metrics.mean_absolute_error(y_test, y_pred_rf)

# Repeat the same for the forth regression(GBR)
s_gbr = metrics.mean_absolute_error(y_test, y_pred_gbr)

# Repeat the same for the fifth regression(XGB)
s_xgb = metrics.mean_absolute_error(y_test, y_pred_xgb)

# Repeat the same for the sixth model(ANN)
s_ann = metrics.mean_absolute_error(y_test, y_pred_ann)

# %%
# Print the result
# The MAE can be used to assess how well each model has performed in predicting the target variable (y_test). 
# A lower MAE indicates a better-performing model with smaller errors between predicted and actual values. 
print(s_lr,s_svm,s_rf,s_gbr,s_xgb,s_ann)
# Out:
# 0.06164836654357026 0.048419854192379166 0.017325474317411303 0.022302108370132672 0.018404867551756767 0.0307546193815393

# %%
score=pd.DataFrame({'Models':['LR','SVM','RF','GB','XGB','ANN'],
             'MAE':[s_lr,s_svm,s_rf,s_gbr,s_xgb,s_ann]})
score
# Out:
#   Models       MAE
# 0     LR  0.061648
# 1    SVM  0.048420
# 2     RF  0.017325
# 3     GB  0.022302
# 4    XGB  0.018405
# 5    ANN  0.030755

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df contains your data
sns.set(style="whitegrid")  # Set the style of the plot

# Create the bar plot
ax = sns.barplot(x='MAE', y='Models', data=score)

# Adding labels and title
plt.xlabel('Mean Absolute Error (MAE)')
plt.ylabel('Models')
plt.title('MAE Comparison for Different Models')

# Add text labels for each bar
for index, row in score.iterrows():
    ax.text(row['MAE'], index, f'{row["MAE"]:.4f}', va='center')

# Display the plot
plt.show()

# %%
# Thus, the RF model is the best model.

# %% [markdown]
# # Save model using joblib

# %%
# Since RF is the best model, I create an instance of the RandomForestRegressor class and assigns it to the variable rf.
rf = RandomForestRegressor()
# Fit (trains) the RandomForestRegressor model to the entire dataset X and the corresponding target variable y. 
rf.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
# Import the joblib library
import joblib

# Save the trained RandomForestRegressor model (rf) to a file named 'Project2_Model_in_Production'. 
# The dump() function from the joblib library is used to serialize the Python object (rf - the trained model) to the file.
joblib.dump(rf,'Project2_Model_in_Production')
# Out:
# ['Project2_Model_in_Production']

# %%
# load the machine learning model stored in the file 'Model_in_Production' into memory and assigns it to the variable model.
model = joblib.load('Project2_Model_in_Production')

# %%
# I can now use this loaded model to make predictions on new data without the need to retrain the model.
